# %%
import pandas as pd
df_last=pd.read_csv("C:/Users/doyeo/OneDrive/Desktop/jupyter/주택도시보증공사_전국 평균 분양가격(2020년 1월).csv",encoding='cp949')
df_last.shape
# Out:
# (4420, 5)

# %%
df_last.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
df_last.tail()
# Out:
#      지역명               규모구분    연도  월 분양가격(㎡)
# 4415  제주                 전체  2020  1    3955
# 4416  제주         전용면적 60㎡이하  2020  1    4039
# 4417  제주   전용면적 60㎡초과 85㎡이하  2020  1    3962
# 4418  제주  전용면적 85㎡초과 102㎡이하  2020  1     NaN
# 4419  제주        전용면적 102㎡초과  2020  1    3601

# %%
df_first=pd.read_csv("C:/Users/doyeo/OneDrive/Desktop/jupyter/전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv",encoding='cp949')
df_first.shape
# Out:
# (17, 22)

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# ...

# %%
df_first.tail()
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 12     6319     6436  ...      6583      6583     6583     6583     6542
# 13     5780     5685  ...      5768      5784     5784     5833     5825
# 14     6556     6563  ...      6881      6989     6992     6953     6997
# 15     6613     6606  ...      7125      7332     7592     7588     7668
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 12     6551     6556     6601     6750     6580
# ...

# %%
df_last.info
# Out:
# <bound method DataFrame.info of      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 4415  제주                 전체  2020   1    3955
# 4416  제주         전용면적 60㎡이하  2020   1    4039
# 4417  제주   전용면적 60㎡초과 85㎡이하  2020   1    3962
# 4418  제주  전용면적 85㎡초과 102㎡이하  2020   1     NaN
# 4419  제주        전용면적 102㎡초과  2020   1    3601
#
# [4420 rows x 5 columns]>

# %%
df_last.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)'], dtype='object')

# %%
True==1
False==0
True+False
# Out:
# 1

# %%
df_last.isna().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    286
# dtype: int64

# %%
df_last["분양가격"]=pd.to_numeric(df_last["분양가격(㎡)"],errors='coerce')
df_last["분양가격"]
# Out:
# 0       5841.0
# 1       5652.0
# 2       5882.0
# 3       5721.0
# 4       5879.0
#          ...
# 4415    3955.0
# 4416    4039.0
# 4417    3962.0
# 4418       NaN
# 4419    3601.0
# Name: 분양가격, Length: 4420, dtype: float64

# %%
#단위맞춰주기
df_last["평당분양가격"]=df_last["분양가격"]*3.3
df_last
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0     서울                 전체  2015  10    5841  5841.0  19275.3
# 1     서울         전용면적 60㎡이하  2015  10    5652  5652.0  18651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0  19410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0  18879.3
# 4     서울        전용면적 102㎡초과  2015  10    5879  5879.0  19400.7
# ...   ..                ...   ...  ..     ...     ...      ...
# 4415  제주                 전체  2020   1    3955  3955.0  13051.5
# 4416  제주         전용면적 60㎡이하  2020   1    4039  4039.0  13328.7
# 4417  제주   전용면적 60㎡초과 85㎡이하  2020   1    3962  3962.0  13074.6
# 4418  제주  전용면적 85㎡초과 102㎡이하  2020   1     NaN     NaN      NaN
# 4419  제주        전용면적 102㎡초과  2020   1    3601  3601.0  11883.3
#
# [4420 rows x 7 columns]

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4420 entries, 0 to 4419
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4420 non-null   object
#  1   규모구분     4420 non-null   object
#  2   연도       4420 non-null   int64
#  3   월        4420 non-null   int64
#  4   분양가격(㎡)  4134 non-null   object
#  5   분양가격     4033 non-null   float64
#  6   평당분양가격   4033 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 241.8+ KB

# %%
df_last["분양가격(㎡)"].describe()
# Out:
# count     4134
# unique    1774
# top       2221
# freq        17
# Name: 분양가격(㎡), dtype: object

# %%
df_last["분양가격"].describe()
#mean,50%값 확인!->max값이 차이가크기때문에 평균이더 크게나온것.
# Out:
# count     4033.000000
# mean      3249.734689
# std       1276.240903
# min       1868.000000
# 25%       2448.000000
# 50%       2884.000000
# 75%       3582.000000
# max      12728.000000
# Name: 분양가격, dtype: float64

# %%
df_last["규모구분"].unique()
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
# 전용면적 글자 제거,공백 제거
df_last["전용면적"]=df_last["규모구분"].str.replace("전용면적","")
df_last["전용면적"]=df_last["전용면적"].str.replace("초과","~")
df_last["전용면적"]=df_last["전용면적"].str.replace("이하","")
df_last["전용면적"]=df_last["전용면적"].str.replace(" ","").str.strip()
df_last["전용면적"]
# Out:
# 0             전체
# 1            60㎡
# 2        60㎡~85㎡
# 3       85㎡~102㎡
# 4          102㎡~
#           ...
# 4415          전체
# 4416         60㎡
# 4417     60㎡~85㎡
# 4418    85㎡~102㎡
# 4419       102㎡~
# Name: 전용면적, Length: 4420, dtype: object

# %%
df_last.head(1)
#df_last=df_last.drop(["규모구분","분양가격(㎡)"],axis=1)
#axis=0행,1열
# Out:
#   지역명 규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격 전용면적
# 0  서울   전체  2015  10    5841  5841.0  19275.3   전체

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4420 entries, 0 to 4419
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4420 non-null   object
#  1   규모구분     4420 non-null   object
#  2   연도       4420 non-null   int64
#  3   월        4420 non-null   int64
#  4   분양가격(㎡)  4134 non-null   object
#  5   분양가격     4033 non-null   float64
#  6   평당분양가격   4033 non-null   float64
#  7   전용면적     4420 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 276.4+ KB

# %%
df_last.groupby(["지역명"]).mean()
df_last.groupby(["지역명"])["평당분양가격"].mean()
#pd.pivot_table(df_last,index=["지역명"],values=["평당분양가격"],aggfunc="mean")
# Out:
# 지역명
# 강원     7927.829150
# 경기    13412.235294
# 경남     9280.875299
# 경북     8403.699184
# 광주    10013.954634
# 대구    12036.903644
# 대전    10299.152970
# 부산    12111.854118
# 서울    23733.729412
# 세종     9829.645643
# 울산    10026.876316
# 인천    11950.641036
# 전남     7583.426190
# 전북     7739.621739
# 제주    11269.855157
# 충남     8250.540984
# 충북     7641.441176
# Name: 평당분양가격, dtype: float64

# %%
df_last.groupby(["전용면적"])["평당분양가격"].mean()
#pd.pivot_table(df_last,index=["전용면적"],values=["평당분양가격"],aggfunc="mean")
# Out:
# 전용면적
# 102㎡~       11561.707538
# 60㎡         10406.061338
# 60㎡~85㎡     10303.150000
# 85㎡~102㎡    11154.605462
# 전체          10308.965385
# Name: 평당분양가격, dtype: float64

# %%
df_last.groupby(["전용면적","지역명"])["평당분양가격"].mean()
#df_last.pivot_table(index=["전용면적"],columns="지역명",values=["평당분양가격"])
# Out:
# 전용면적   지역명
# 102㎡~  강원      8400.182353
#        경기     14818.876471
#        경남     10358.363265
#        경북      9201.435294
#        광주     11125.255263
#                   ...
# 전체     전남      7301.541176
#        전북      7309.305882
#        제주     10829.435294
#        충남      7832.905882
#        충북      7226.611765
# Name: 평당분양가격, Length: 85, dtype: float64

# %%
df_last.groupby(["지역명","전용면적"])["평당분양가격"].mean().unstack().round()
# Out:
# 전용면적    102㎡~      60㎡  60㎡~85㎡  85㎡~102㎡       전체
# 지역명
# 강원     8400.0   7584.0   7498.0    8802.0   7492.0
# 경기    14819.0  13311.0  12563.0   13763.0  12605.0
# 경남    10358.0   8699.0   8648.0   10031.0   8687.0
# 경북     9201.0   7895.0   8101.0    8774.0   8119.0
# 광주    11125.0   9507.0   9966.0    9296.0   9958.0
# 대구    13162.0  12037.0  11834.0   11194.0  11826.0
# 대전    14876.0   9232.0   9752.0    9037.0   9829.0
# 부산    13229.0  11371.0  11885.0   12121.0  11953.0
# 서울    23554.0  23297.0  22866.0   26259.0  22692.0
# 세종    10163.0   9324.0   9803.0    9882.0   9837.0
# 울산     9974.0   9269.0  10497.0    8861.0  10490.0
# 인천    14391.0  11279.0  11420.0   11559.0  11295.0
# 전남     8206.0   7232.0   7288.0    7909.0   7302.0
# 전북     8205.0   7624.0   7288.0    8293.0   7309.0
# 제주    10551.0  14004.0  10669.0   10709.0  10829.0
# 충남     8702.0   7910.0   7838.0    9155.0   7833.0
# 충북     8198.0   7114.0   7271.0    8397.0   7227.0

# %%
df_last.groupby(["연도","지역명"])["평당분양가격"].mean().unstack()
#df_last.groupby(["연도","지역명"])["평당분양가격"].mean().unstack().T
# Out:
# 지역명            강원        경기            경남            경북            광주  \
# 연도
# 2015  7188.060000  11060.94   8459.220000   7464.160000   7916.700000
# 2016  7162.903846  11684.97   8496.730000   7753.405000   9190.683333
# 2017  7273.560000  12304.98   8786.760000   8280.800000   9613.977551
# 2018  8219.255000  14258.42   9327.670000   8680.776923   9526.953333
# 2019  8934.475000  15665.54  10697.615789   9050.250000  12111.675000
# 2020  9722.460000  16179.24  10027.875000  10040.250000  13150.500000
#
# 지역명             대구            대전         부산         서울            세종  \
# 연도
# 2015   9018.900000   8190.600000  10377.400  20315.680   8765.020000
# 2016  10282.030000   8910.733333  10743.535  21753.435   8857.805000
# 2017  12206.700000   9957.158491  11560.680  21831.060   9132.505556
# 2018  12139.252632  10234.106667  12889.965  23202.245  10340.463158
# 2019  14081.650000  12619.200000  13537.865  28286.830  11299.394118
# ...

# %%
g=df_last.groupby(["연도","지역명"])["평당분양가격"].mean()
g
#p=pd.pivot_table(df_last,index=["연도","지역명"],values="평당분양가격")
#p.loc[2018]
# Out:
# 연도    지역명
# 2015  강원      7188.060
#       경기     11060.940
#       경남      8459.220
#       경북      7464.160
#       광주      7916.700
#                ...
# 2020  전남      8706.225
#       전북      8502.780
#       제주     12834.525
#       충남      9057.840
#       충북      7980.720
# Name: 평당분양가격, Length: 102, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.rc("font",family="Malgun Gothic")

# %%
g=df_last.groupby(["지역명"])["평당분양가격"].mean().sort_values()#(ascending=False)
g.plot()

# %%
g.plot.bar(rot=0,figsize=(10,3))

# %%
df_last.groupby(["전용면적"])["평당분양가격"].mean().plot.bar()

# %%
df_last.groupby(["연도"])["평당분양가격"].mean().plot()

# %%
df_last.pivot_table(index="연도",values="평당분양가격").plot.box()

# %%
df_last.pivot_table(index="월",columns="연도",values="평당분양가격").plot.box()

# %%
p=df_last.pivot_table(index="월",columns=["연도","전용면적"],values="평당분양가격")
p.plot.box(rot=30,figsize=(15,3))

# %%
import seaborn as sns

# %%
# ci=신뢰도 기본적으로95%값
sns.barplot(data=df_last,x="지역명",y="평당분양가격",ci=None,color=None)
plt.figure(figsize=(10,5))

# %%
sns.barplot(data=df_last,x="연도",y="평당분양가격")

# %%
#subplot을 그릴수있다! 기본적으로 산점도로나옴. kind로 바꾸기
sns.catplot(data=df_last,x="연도",y="평당분양가격",kind="bar",col="지역명",col_wrap=4)

# %%
sns.lineplot(data=df_last,x="연도",y="평당분양가격",hue="지역명")
#plt.figure(figsize=(15,3))
plt.legend(loc='1',bbox_to_anchor=(1.05,1))
# Out:
# C:\Users\doyeo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Unrecognized location '1'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#subplot을 그릴수있다! 기본적으로 산점도로나옴. kind로 바꾸기
sns.relplot(data=df_last,x="연도",y="평당분양가격",hue="지역명",kind="line",col="지역명",col_wrap=4)

# %%
sns.boxplot(data=df_last,x="연도",y="평당분양가격",hue="전용면적")
plt.figure(figsize=(12,3))

# %%
#boxplot안의 값들의변화를 더 잘보기위해
sns.violinplot(data=df_last,x="연도",y="평당분양가격")

# %%
#산포도+회귀선도 그려줌
sns.regplot(data=df_last,x="연도",y="평당분양가격")

# %%
sns.lmplot(data=df_last,x="연도",y="평당분양가격",hue="전용면적",col="전용면적",col_wrap=3)

# %%
#swarmplot은 범주형(카테고리) 데이터의 산점도를 그릴떄 유리
#산점도는 숫자값데이터간의 연관성볼때
sns.swarmplot(data=df_last,x="연도",y="평당분양가격")
# Out:
# C:\Users\doyeo\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\doyeo\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.swarmplot(data=df_last,x="연도",y="평당분양가격", hue="전용면적")

# %%
# 이상치 찾아보기
df_last["평당분양가격"].describe()
# Out:
# count     4033.000000
# mean     10724.124473
# std       4211.594980
# min       6164.400000
# 25%       8078.400000
# 50%       9517.200000
# 75%      11820.600000
# max      42002.400000
# Name: 평당분양가격, dtype: float64

# %%
max_price=df_last["평당분양가격"].max()
max_price
# Out:
# 42002.399999999994

# %%
df_last[df_last["평당분양가격"]==max_price]
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)     분양가격   평당분양가격      전용면적
# 3743  서울  전용면적 85㎡초과 102㎡이하  2019   6   12728  12728.0  42002.4  85㎡~102㎡
# 3828  서울  전용면적 85㎡초과 102㎡이하  2019   7   12728  12728.0  42002.4  85㎡~102㎡
# 3913  서울  전용면적 85㎡초과 102㎡이하  2019   8   12728  12728.0  42002.4  85㎡~102㎡
# 3998  서울  전용면적 85㎡초과 102㎡이하  2019   9   12728  12728.0  42002.4  85㎡~102㎡
# 4083  서울  전용면적 85㎡초과 102㎡이하  2019  10   12728  12728.0  42002.4  85㎡~102㎡
# 4168  서울  전용면적 85㎡초과 102㎡이하  2019  11   12728  12728.0  42002.4  85㎡~102㎡
# 4253  서울  전용면적 85㎡초과 102㎡이하  2019  12   12728  12728.0  42002.4  85㎡~102㎡
# 4338  서울  전용면적 85㎡초과 102㎡이하  2020   1   12728  12728.0  42002.4  85㎡~102㎡

# %% [markdown]
# #수치화데이터

# %%
h=df_last["평당분양가격"].hist(bins=10)

# %%
#결측치가 없는 데이터에서 평당분양가격만 가져온다.
price=df_last.loc[df_last["평당분양가격"].notnull(),"평당분양가격"]

# %%
sns.distplot(price)

# %%
#sns.distplot(price,hist=False,rug=True)
sns.kdeplot(price)
#sns.kdeplot(price, cumulative=True) 누적그래프

# %%
#산마루 그래프
g=sns.FacetGrid(df_last,row="지역명",height=1.7,aspect=4)
g.map(sns.distplot,"평당분양가격",hist=False,rug=True)

# %%
sns.pairplot(df_last)

# %%
df_last_nn=df_last.loc[df_last["평당분양가격"].notnull(),["연도","월","평당분양가격","지역명","전용면적"]]
sns.pairplot(df_last_nn,hue="전용면적")

# %%
df_last_nn=df_last.loc[df_last["평당분양가격"].notnull(),["연도","월","평당분양가격","지역명","전용면적"]]
sns.pairplot(df_last_nn,hue="지역명")

# %%
df_last["전용면적"].value_counts()
# Out:
# 60㎡~85㎡     884
# 전체          884
# 85㎡~102㎡    884
# 102㎡~       884
# 60㎡         884
# Name: 전용면적, dtype: int64

# %%
pd.options.display.max_columns=25
df_first
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
df_first.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %%
df_first.head(1)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    19415    18842    18367    18374    18152    18443

# %%
df_first.melt=df_first.melt(id_vars="지역",var_name="기간",value_name="평당분양가격")
df_first.melt.head(1)
# Out:
#    지역        기간  평당분양가격
# 0  서울  2013년12월   18189

# %%
df_first.melt.columns=["지역명","기간","평당분양가격"]
df_first.melt.head(1)
# Out:
#   지역명        기간  평당분양가격
# 0  서울  2013년12월   18189

# %%
date="2013년12월"
date
# Out:
# '2013년12월'

# %%
date.split("년")
# Out:
# ['2013', '12월']

# %%
date.split("년")[0]
# Out:
# '2013'

# %%
date.split("년")[-1].replace("월","")
# Out:
# '12'

# %%
def parse_year(date):
    year=date.split("년")[0]
    year=int(year)
    return year
parse_year(date)
# Out:
# 2013

# %%
def parse_month(date):
    month=date.split("년")[-1].replace("월","")
    month=int(month)
    return month
parse_month(date)
# Out:
# 12

# %%
df_first.melt["연도"]=df_first.melt["기간"].apply(parse_year)
df_first.melt.head(1)
# Out:
#   지역명        기간  평당분양가격    연도
# 0  서울  2013년12월   18189  2013

# %%
df_first.melt["월"]=df_first.melt["기간"].apply(parse_month)
df_first.melt.head(1)
# Out:
#   지역명        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12

# %%
df_last.sample()
# Out:
#      지역명         규모구분    연도  월 분양가격(㎡)    분양가격   평당분양가격   전용면적
# 3559  경북  전용면적 102㎡초과  2019  3    3098  3098.0  10223.4  102㎡~

# %%
df_last.columns.to_list()
# Out:
# ['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격', '전용면적']

# %%
cols=['지역명', '연도', '월','평당분양가격']

# %%
#이전데이터에는 전용면적이없기떄문에 전체인것만 가져온다.
df_last_prepare=df_last.loc[df_last["전용면적"]=="전체",cols].copy()
df_last_prepare
# Out:
#      지역명    연도   월   평당분양가격
# 0     서울  2015  10  19275.3
# 5     인천  2015  10  10437.9
# 10    경기  2015  10  10355.4
# 15    부산  2015  10  10269.6
# 20    대구  2015  10   8850.6
# ...   ..   ...  ..      ...
# 4395  전북  2020   1   8144.4
# 4400  전남  2020   1   8200.5
# 4405  경북  2020   1  10144.2
# 4410  경남  2020   1  10107.9
# 4415  제주  2020   1  13051.5
#
# [884 rows x 4 columns]

# %%
df_first.melt
# Out:
#     지역명        기간  평당분양가격    연도   월
# 0    서울  2013년12월   18189  2013  12
# 1    부산  2013년12월    8111  2013  12
# 2    대구  2013년12월    8080  2013  12
# 3    인천  2013년12월   10204  2013  12
# 4    광주  2013년12월    6098  2013  12
# ..   ..       ...     ...   ...  ..
# 352  전북   2015년8월    6580  2015   8
# 353  전남   2015년8월    6289  2015   8
# 354  경북   2015년8월    7037  2015   8
# 355  경남   2015년8월    7665  2015   8
# 356  제주   2015년8월    7343  2015   8
#
# [357 rows x 5 columns]

# %%
df_first_prepare=df_first.melt[cols].copy()
df_first_prepare
# Out:
#     지역명    연도   월  평당분양가격
# 0    서울  2013  12   18189
# 1    부산  2013  12    8111
# 2    대구  2013  12    8080
# 3    인천  2013  12   10204
# 4    광주  2013  12    6098
# ..   ..   ...  ..     ...
# 352  전북  2015   8    6580
# 353  전남  2015   8    6289
# 354  경북  2015   8    7037
# 355  경남  2015   8    7665
# 356  제주  2015   8    7343
#
# [357 rows x 4 columns]

# %%
df=pd.concat([df_first_prepare,df_last_prepare])
df.shape
# Out:
# (1241, 4)

# %%
df.head()
# Out:
#   지역명    연도   월   평당분양가격
# 0  서울  2013  12  18189.0
# 1  부산  2013  12   8111.0
# 2  대구  2013  12   8080.0
# 3  인천  2013  12  10204.0
# 4  광주  2013  12   6098.0

# %%
df["연도"].value_counts()
# Out:
# 2019    204
# 2018    204
# 2017    204
# 2016    204
# 2014    204
# 2015    187
# 2020     17
# 2013     17
# Name: 연도, dtype: int64

# %%
t=pd.pivot_table(df,index="연도",columns="지역명",values="평당분양가격").round()
t
# Out:
# 지역명       강원       경기       경남       경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0   6473.0   6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0   6729.0   6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0   7646.0   7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0   7848.0   7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7127.0  11850.0   8120.0   7795.0   9464.0  11456.0   9045.0  11578.0
# 2018  7681.0  13186.0   9019.0   8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0   9871.0   8857.0  11823.0  13852.0  11778.0  13116.0
# 2020  8207.0  14860.0  10108.0  10144.0  12682.0  14586.0  11986.0  12817.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# 2014  18997.0   8085.0   8362.0  10075.0  5719.0  6362.0   7855.0  6682.0
# ...

# %%
plt.figure(figsize=(20,7))
sns.heatmap(t,cmap="Blues",annot=True,fmt=".0f")

# %%
#행열바꾸기
t.T
# Out:
# 연도      2013     2014     2015     2016     2017     2018     2019     2020
# 지역명
# 강원    6230.0   6332.0   6831.0   7011.0   7127.0   7681.0   8142.0   8207.0
# 경기   10855.0  10509.0  10489.0  11220.0  11850.0  13186.0  14469.0  14860.0
# 경남    6473.0   6729.0   7646.0   7848.0   8120.0   9019.0   9871.0  10108.0
# 경북    6168.0   6536.0   7035.0   7361.0   7795.0   8505.0   8857.0  10144.0
# 광주    6098.0   7588.0   7956.0   8899.0   9464.0   9856.0  11823.0  12682.0
# 대구    8080.0   8286.0   8707.0  10310.0  11456.0  12076.0  13852.0  14586.0
# 대전    8321.0   8240.0   8105.0   8502.0   9045.0  10180.0  11778.0  11986.0
# 부산    8111.0   9180.0   9633.0  10430.0  11578.0  12998.0  13116.0  12817.0
# 서울   18189.0  18997.0  19283.0  20663.0  21376.0  22889.0  26131.0  26799.0
# 세종    7601.0   8085.0   8641.0   8860.0   9135.0  10355.0  11079.0  11411.0
# 울산    8090.0   8362.0   9273.0  10209.0  11345.0  10241.0  10022.0  10372.0
# ...

# %%
sns.heatmap(t.T,cmap="Blues",annot=True,fmt=".0f")
plt.figure(figsize=(20,7))

# %%
g=df.groupby(["연도","지역명"])["평당분양가격"].mean().unstack().round()
g
# Out:
# 지역명       강원       경기       경남       경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0   6473.0   6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0   6729.0   6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0   7646.0   7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0   7848.0   7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7127.0  11850.0   8120.0   7795.0   9464.0  11456.0   9045.0  11578.0
# 2018  7681.0  13186.0   9019.0   8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0   9871.0   8857.0  11823.0  13852.0  11778.0  13116.0
# 2020  8207.0  14860.0  10108.0  10144.0  12682.0  14586.0  11986.0  12817.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# 2014  18997.0   8085.0   8362.0  10075.0  5719.0  6362.0   7855.0  6682.0
# ...

# %%
plt.figure(figsize=(20,7))
sns.heatmap(g.T,cmap="Greens",annot=True,fmt=".0f")

# %%
sns.barplot(data=df,x="연도",y="평당분양가격")

# %%
sns.pointplot(data=df,x="연도",y="평당분양가격",hue="지역명")
plt.legend(bbox_to_anchor=(1.2,1),loc=1)

# %%
df_seoul=df[df["지역명"]=="서울"].copy()
df_seoul
# Out:
#      지역명    연도   월   평당분양가격
# 0     서울  2013  12  18189.0
# 17    서울  2014   1  17925.0
# 34    서울  2014   2  17925.0
# 51    서울  2014   3  18016.0
# 68    서울  2014   4  18098.0
# ...   ..   ...  ..      ...
# 3995  서울  2019   9  26680.5
# 4080  서울  2019  10  26700.3
# 4165  서울  2019  11  26604.6
# 4250  서울  2019  12  26251.5
# 4335  서울  2020   1  26799.3
#
# [73 rows x 4 columns]

# %%
sns.barplot(data=df_seoul,x="연도",y="평당분양가격")
sns.pointplot(data=df_seoul,x="연도",y="평당분양가격")

# %%
sns.boxplot(data=df,x="연도",y="평당분양가격")

# %%
sns.boxenplot(data=df,x="연도",y="평당분양가격")

# %%
sns.violinplot(data=df,x="연도",y="평당분양가격")

# %%
sns.lmplot(data=df,x="연도",y="평당분양가격")

# %%
sns.swarmplot(data=df,x="연도",y="평당분양가격",hue="지역명")
plt.legend(bbox_to_anchor=(1.2,1),loc=1)

# %%
sns.violinplot(data=df,x="연도",y="평당분양가격")
sns.swarmplot(data=df,x="연도",y="평당분양가격",hue="지역명")
plt.legend(bbox_to_anchor=(1.2,1),loc=1)
# Out:
# C:\Users\doyeo\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\doyeo\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.barplot(data=df,x="지역명",y="평당분양가격")

# %%
sns.boxplot(data=df,x="지역명",y="평당분양가격")

# %%
sns.boxenplot(data=df,x="지역명",y="평당분양가격")

# %%
sns.violinplot(data=df,x="지역명",y="평당분양가격")

# %%
sns.swarmplot(data=df,x="지역명",y="평당분양가격",hue="연도")
